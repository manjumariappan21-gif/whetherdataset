# %% [markdown]
# <a href="https://colab.research.google.com/github/manjumariappan21-gif/whetherdataset/blob/main/whether_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
file_path="/content/drive/MyDrive/weather_data.csv"

# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv(file_path)

# %%
data.head()
# Out:
#        Location            Date_Time  Temperature_C  Humidity_pct  \
# 0     San Diego  2024-01-14 21:12:46      10.683001     41.195754
# 1     San Diego  2024-05-17 15:22:10       8.734140     58.319107
# 2     San Diego  2024-05-11 09:30:59      11.632436     38.820175
# 3  Philadelphia  2024-02-26 17:32:39      -8.628976     54.074474
# 4   San Antonio  2024-04-29 13:23:51      39.808213     72.899908
#
#    Precipitation_mm  Wind_Speed_kmh
# 0          4.020119        8.233540
# 1          9.111623       27.715161
# 2          4.607511       28.732951
# 3          3.183720       26.367303
# 4          9.598282       29.898622

# %%
import pandas as pd
data = {
    "Date": ["2024-01-01", "2024-01-02", "2024-01-03", "2024-01-04", "2024-01-05"],
    "Temperature (°C)": [30, 32, 31, 29, 33],
    "Humidity (%)": [65, 70, 68, 72, 66],
    "Rainfall (mm)": [5, 0, 10, 2, 0],
    "Wind Speed (km/h)": [12, 15, 10, 8, 14]
}
weather_dataset = pd.DataFrame(data)
print(weather_dataset)
# Out:
#          Date  Temperature (°C)  Humidity (%)  Rainfall (mm)  \
# 0  2024-01-01                30            65              5
# 1  2024-01-02                32            70              0
# 2  2024-01-03                31            68             10
# 3  2024-01-04                29            72              2
# 4  2024-01-05                33            66              0
#
#    Wind Speed (km/h)
# 0                 12
# 1                 15
# 2                 10
# 3                  8
# 4                 14
